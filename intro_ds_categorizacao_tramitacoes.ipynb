# %% [markdown]
# ## Categorização de Tramitações de Projetos de Lei da Câmara dos Deputados
# ### Análise Exploratória dos dados de tramitação
#
# **Autora**: Fernanda Scovino (FGV-EMAp)
#
# ### Objetivo
# ---
# Criar uma classificação das tramitações de Projetos de Lei da Câmara dos Deputados a partir da análise de proximidade do seus textos de descrição.
#
# **Base de dados:** [Dados de andamento dos Projetos de Lei de 1988 a 2018, disponíveis na API dos Dados Abertos da Câmara](http://www2.camara.leg.br/transparencia/dados-abertos/dados-abertos-legislativo/webservices/orgaos/obterandamento)
#
# ### Metodologia
# ---
# A partir dos dados de descrição das tramitações, vamos utilizar pacotes como `nltk`, `gensim` e `tfidf` para verificar a frequência e a similaridade de palavras nos textos para identificarmos palavras chaves. Essas palavras chaves vão servir futuramente para categorizarmos as tramitações de acordo com os *clusters* gerados pelo algoritmo de *Topic Model*.
#
# ### Considerações
# ---
#
# Na redução ao radical das palavaras foi utilizado o método *stemmer* do pacote `nltk`, que "corta" as palavras ao invés de reduzí-las a um lema, como é feito no método *lemmatizer*, pois este último não tem versão para português. Isso prejudica um pouco a leitura e o entendimento das palavras, que às vezes tem um corte muito drástico.

# %%
# DATA ANALYSIS
from copy import deepcopy
import pandas as pd

pd.options.display.max_columns = 999

import re
import nltk
import string
import gensim
import textract
import networkx as nx
from collections import Counter
from wordcloud import WordCloud

# VIZ TOOLS
import plotly
import plotly.graph_objs as go
import plotly.offline as offline

offline.init_notebook_mode(connected=True)

# %pylab inline
pylab.rcParams['figure.figsize'] = (12, 12)

colorscale = ['#dee0e0', '#b9bfbf', '#00D9FF', '#7c8282', '#0095D4', '#b5dde5', '#04b9d3', '#1C5D96'] # visual id

# FILES STORAGE
import os
cwd = os.getcwd()

RAW_DATA = cwd+'/raw_data/' # put primary data here
DATASET = cwd+'/datasets/' # put processed data here
GRAPH = cwd+'/graphs'
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## IMPORTANTE!  NÃO RODAR AQUI!
#
# ### Como o arquivo 'trams_pls' é muito grande, não segui importar para o GitHub, mas os resultados da análise ainda estão aqui.
#
# ## Rode os dados a partir daqui: [Amostragem](#amostra)

# %% [markdown]
# ### Importação dos dados

# %%
trams_pls = pd.read_csv(RAW_DATA+'trams_pls.csv')

# %%
trams_pls.columns
# Out:
# Index(['Unnamed: 0', 'index', 'idProposicao', 'ementa', 'situacao', 'numero',
#        'ano', 'tipo', 'ultimaAcao_tramitacao_codOrgao',
#        'ultimaAcao_tramitacao_orgao', 'ultimaAcao_tramitacao_descricao',
#        'ultimaAcao_tramitacao_data', 'ultimaAcao_tramitacao_ordemDeTramitacao',
#        'andamento_tramitacao_codOrgao', 'andamento_tramitacao_Orgao',
#        'andamento_tramitacao_descricao', 'andamento_tramitacao_inteiroTeor',
#        'andamento_tramitacao_codReuniao', 'andamento_tramitacao_data',
#        'andamento_tramitacao_ordemDeTramitacao', 'data_captura'],
#       dtype='object')

# %% [markdown]
# Abaixo podemos ver que as colunas `andamento_tramitacao_inteiroTeor` e `andamento_tramitacao_codReuniao` têm muitos dados faltantes, cerca de  60% e 90% dos valores nas colunas são nulos, respectivamente.
#
# Outras colunas, como `andamento_tramitacao_codOrgao`, `andamento_tramitacao_Orgao`,  `andamento_tramitacao_descricao`, `andamento_tramitacao_data` e `andamento_tramitacao_ordemDeTramitacao` também possuem valores nulos, mas que correpondem a somente 0,02% do total, aproximadamente.

# %%
trams_pls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1428907 entries, 0 to 1428906
# Data columns (total 21 columns):
# Unnamed: 0                                 1428907 non-null int64
# index                                      1428907 non-null int64
# idProposicao                               1428907 non-null int64
# ementa                                     1428907 non-null object
# situacao                                   1428907 non-null object
# numero                                     1428907 non-null int64
# ano                                        1428907 non-null int64
# tipo                                       1428907 non-null object
# ultimaAcao_tramitacao_codOrgao             1428907 non-null int64
# ultimaAcao_tramitacao_orgao                1428907 non-null object
# ultimaAcao_tramitacao_descricao            1427607 non-null object
# ultimaAcao_tramitacao_data                 1428907 non-null object
# ultimaAcao_tramitacao_ordemDeTramitacao    1428907 non-null int64
# andamento_tramitacao_codOrgao              1428672 non-null float64
# andamento_tramitacao_Orgao                 1428672 non-null object
# andamento_tramitacao_descricao             1428572 non-null object
# andamento_tramitacao_inteiroTeor           584101 non-null object
# andamento_tramitacao_codReuniao            139396 non-null float64
# andamento_tramitacao_data                  1428672 non-null object
# andamento_tramitacao_ordemDeTramitacao     1428672 non-null float64
# data_captura                               1428907 non-null object
# dtypes: float64(3), int64(7), object(11)
# memory usage: 228.9+ MB

# %%
trams_pls.head()
# Out:
#    Unnamed: 0  index  idProposicao  \
# 0           0   7791        575557
# 1           1   7791        582462
# 2           2   7791        584235
# 3           3   7791        589897
# 4           4   7791        598740
#
#                                               ementa  \
# 0  Cria Área de Livre Comércio no Município de Pa...
# 1  Acrescenta alínea ao inciso II do art. 8º da L...
# 2  Altera a redação do § 3º do art. 71 da Consoli...
# 3  Altera a Lei nº 12.305, de 2 de agosto de 2010...
# 4  Altera dispositivo da Consolidação das Leis do...
#
#                                  situacao  numero   ano tipo  \
# 0                        MESA - Arquivada    5494  2013   PL
# 1  CPD - Aguardando Designação de Relator    5854  2013   PL
# 2                        MESA - Arquivada    5909  2013   PL
# 3                        MESA - Arquivada    6228  2013   PL
# 4           CSSF - Tramitando em Conjunto    6659  2013   PL
#
#    ultimaAcao_tramitacao_codOrgao  \
# 0                               4
# 1                          537480
# 2                               4
# 3                               4
# 4                               4
#
#                          ultimaAcao_tramitacao_orgao  \
# 0  MESA       - Mesa Diretora da Câmara dos Deput...
# 1  CPD        - Comissão de Defesa dos Direitos d...
# 2  MESA       - Mesa Diretora da Câmara dos Deput...
# 3  MESA       - Mesa Diretora da Câmara dos Deput...
# 4  MESA       - Mesa Diretora da Câmara dos Deput...
#
#                      ultimaAcao_tramitacao_descricao  \
# 0  Arquivado nos termos do Artigo 105 do Regiment...
# 1  Recebimento pela CPD, com as proposições PL-34...
# 2  Arquivado nos termos do § 4° do art. 164 do RI...
# 3  Arquivado, nos termos do art. 163 c/c o art.16...
# 4  Indeferido o Requerimento n. 3.629/2015, confo...
#
#   ultimaAcao_tramitacao_data  ultimaAcao_tramitacao_ordemDeTramitacao  \
# 0        2015-01-31 00:00:00                                       61
# 1        2018-02-26 00:00:00                                       97
# 2        2018-02-28 00:00:00                                       28
# 3        2017-12-11 00:00:00                                       28
# 4        2016-01-12 00:00:00                                       32
#
#    andamento_tramitacao_codOrgao andamento_tramitacao_Orgao  \
# 0                         2017.0                     CINDRA
# 1                            4.0                       MESA
# 2                            4.0                       MESA
# 3                            4.0                       MESA
# 4                         2008.0                      CDEIC
#
#                       andamento_tramitacao_descricao  \
# 0  Apresentação do Parecer do Relator, PRL 3 CIND...
# 1             Apense-se a este(a) o(a) PL-1915/2015.
# 2  Sujeito a arquivamento, nos termos do § 4º do ...
# 3  Apense-se à(ao) PL-5089/2013.Proposição Sujeit...
# 4                            Recebimento pela CDEIC.
#
#                     andamento_tramitacao_inteiroTeor  \
# 0  http://www.camara.gov.br/proposicoesWeb/prop_m...
# 1  http://www.camara.gov.br/proposicoesWeb/prop_m...
# 2                                                NaN
# 3  http://www.camara.gov.br/proposicoesWeb/prop_m...
# 4                                                NaN
#
#    andamento_tramitacao_codReuniao andamento_tramitacao_data  \
# 0                              NaN       2013-11-29 00:00:00
# 1                              NaN       2015-06-23 00:00:00
# 2                              NaN       2018-02-07 00:00:00
# 3                              NaN       2013-09-09 00:00:00
# 4                              NaN       2013-11-13 00:00:00
#
#    andamento_tramitacao_ordemDeTramitacao         data_captura
# 0                                    30.0  2018-03-22 19:20:47
# 1                                    33.0  2018-03-22 19:23:36
# 2                                    26.0  2018-03-23 04:51:15
# 3                                    11.0  2018-03-23 00:13:13
# 4                                    17.0  2018-03-23 04:57:12

# %% [markdown]
# Pelo que vemos acima, as primeiras colunas da tabela contém informações permanentes de uma proposição como `idProposicao`, `ementa`, `numero`, `ano` e `tipo`, que caracterizam a mesma.

# %%
trams_pls.tipo.unique()
# Out:
# array(['PL'], dtype=object)

# %%
print(trams_pls.ano.min())
print(trams_pls.ano.max())
# Out:
# 1988
# 2018

# %% [markdown]
# As colunas iniciadas com `ultimaAcao_tramitacao` referem-se à situação atual do projeto de lei, logo, são valores únicos para cada ṕrojeto.
#
# Podemos verificar isso na contagem abaixo:

# %%
ultima_acao = trams_pls[['idProposicao', 
                         'ultimaAcao_tramitacao_codOrgao',
                         'ultimaAcao_tramitacao_orgao', 
                         'ultimaAcao_tramitacao_descricao',
                         'ultimaAcao_tramitacao_data', 
                         'ultimaAcao_tramitacao_ordemDeTramitacao']].drop_duplicates()

ultima_acao.groupby('idProposicao').count().sort_values('ultimaAcao_tramitacao_descricao', ascending=False)[:10]
# Out:
#               ultimaAcao_tramitacao_codOrgao  ultimaAcao_tramitacao_orgao  \
# idProposicao
# 493149                                     2                            2
# 1579163                                    2                            2
# 490263                                     2                            2
# 14919                                      1                            1
# 474475                                     1                            1
# 474140                                     1                            1
# 474141                                     1                            1
# 474175                                     1                            1
# 474199                                     1                            1
# 474200                                     1                            1
#
#               ultimaAcao_tramitacao_descricao  ultimaAcao_tramitacao_data  \
# idProposicao
# 493149                                      2                           2
# 1579163                                     2                           2
# 490263                                      2                           2
# 14919                                       1                           1
# 474475                                      1                           1
# 474140                                      1                           1
# 474141                                      1                           1
# 474175                                      1                           1
# 474199                                      1                           1
# 474200                                      1                           1
#
#               ultimaAcao_tramitacao_ordemDeTramitacao
# idProposicao
# 493149                                              2
# 1579163                                             2
# 490263                                              2
# 14919                                               1
# 474475                                              1
# 474140                                              1
# 474141                                              1
# 474175                                              1
# 474199                                              1
# 474200                                              1

# %% [markdown]
# As colunas iniciadas com `andamento` carregam informações de cada tramitação dos projetos de lei, como o órgão e a data das tramitações.
#
# Em especial, a coluna `andamento_tramitacao_descricao` nos fornece o texto de descrição, como qual iremos trabalhar.

# %% [markdown]
# Existem 335 linhas com dados faltantes nessa coluna, que iremos desconsiderar por não ser uma quantidade representativa do total.

# %%
trams_pls[trams_pls.andamento_tramitacao_descricao.isnull()] # missing data
# Out:
#          Unnamed: 0  index  idProposicao  \
# 11463         11463   7980         18568
# 14254         14254   8023       2092208
# 14318         14318   8024       2092208
# 17265         17265   8071        588807
# 19590         19590   8109       2092207
# 19649         19649   8110       2092207
# 182934       182934  10748        354183
# 187855       187855  10826        372158
# 187912       187912  10827        372158
# 187944       187944  10827       2023981
# 234555       234555  11658       2023981
# 235927       235927  11684        457800
# 261011       261011  12181        316664
# 269825       269825  12363        406485
# 296123       296123  12879        406481
# 308076       308076  13143        592761
# 318298       318298  13375        592761
# 321082       321082  13531        407106
# 328798       328798  13614       2169011
# 328831       328831  13615       2168399
# 328879       328879  13616       2168377
# 328920       328920  13617       2168640
# 328961       328961  13618       2168955
# 329001       329001  13619       2168599
# 329043       329043  13620       2168930
# 329085       329085  13621       2167803
# 329132       329132  13622       2168162
# 329175       329175  13623       2167690
# 329215       329215  13624       2169037
# 329257       329257  13625       2168440
# ...             ...    ...           ...
# 1073488     1073488   2728       2166565
# 1073562     1073562   2729       2166122
# 1074544     1074544   2743       2165157
# 1075112     1075112   2751       2166139
# 1089560     1089560   2961        568722
# 1094050     1094050   3027        437312
# 1135405     1135405   3614        439028
# 1155647     1155647   3898       1194767
# 1188654     1188654   4368         21203
# 1198968     1198968   4512        350993
# 1199694     1199694   4522        510057
# 1199983     1199983   4526        498262
# 1200618     1200618   4535        353734
# 1230395     1230395   4938        353411
# 1231682     1231682   4955        203527
# 1238041     1238041   5038        491324
# 1257303     1257303   5298        442708
# 1261244     1261244   5354        568722
# 1276715     1276715   5563        459566
# 1280105     1280105   5610         18062
# 1280857     1280857   5620         18150
# 1281597     1281597   5630         18148
# 1282324     1282324   5640         18149
# 1283024     1283024   5650         18036
# 1342472     1342472   6539        473697
# 1346058     1346058   6592       1194767
# 1349194     1349194   6642        379393
# 1387687     1387687   7199        592761
# 1412406     1412406   7550       2093176
# 1412476     1412476   7551       2093176
#
#                                                     ementa  \
# 11463    Dispõe sobre o salário mínimo e a manutenção d...
# 14254    Altera os artigos 155, 157, 180 e 266 do Decre...
# 14318    Altera os artigos 155, 157, 180 e 266 do Decre...
# 17265    Regulamenta as atividades de operador de Marke...
# 19590    Altera o artigo 184 da Lei Geral de Telecomuni...
# 19649    Altera o artigo 184 da Lei Geral de Telecomuni...
# 182934   Dispõe sobre a padronização, o registro, a ins...
# 187855          Dispõe sobre a música e os eventos gospel.
# 187912          Dispõe sobre a música e os eventos gospel.
# 187944   Dispõe sobre o visto temporário para o estrang...
# 234555   Dispõe sobre o visto temporário para o estrang...
# 1261244                                   MESA - Arquivada    5202  2013   PL
# 1276715                                   MESA - Arquivada    5782  2009   PL
# 1280105                                   MESA - Arquivada    2396  2000   PL
# 1280857                                   MESA - Arquivada    2457  2000   PL
# 1281597                                   MESA - Arquivada    2455  2000   PL
# 1282324                                   MESA - Arquivada    2456  2000   PL
# 1283024                                   MESA - Arquivada    2377  2000   PL
# 1342472         Tranformada no(a) Lei Ordinária 13063/2014    7153  2010   PL
# 1346058                                   MESA - Arquivada     975  2015   PL
# 1349194                                   MESA - Arquivada    2545  2007   PL
# 1387687                                           Diversas    6387  2013   PL
# 1412406                      PLEN - Tramitando em Conjunto    5936  2016   PL
# 1412476                      PLEN - Tramitando em Conjunto    5936  2016   PL
#
#          ultimaAcao_tramitacao_codOrgao  \
# 11463                                 4
# 14254                              2003
# 14318                              2003
# 17265                               180
# 19590                              2003
# 19649                              2003
# 182934                              186
# 187855                                4
# 187912                                4
# 187944                                4
# 234555                                4
# 235927                                4
# 261011                                4
# 269825                                4
# 296123                                4
# 308076                             2004
# 318298                             2004
# 321082                                4
# 328798                              180
# 328831                              180
# 328879                              180
# 328920                              180
# 328961                              180
# 329001                              180
# 329043                              180
# 329085                              180
# 329132                              180
# 329175                              180
# 329215                              180
# 329257                              180
# ...                                 ...
# 1073488                             180
# 1073562                             180
# 1074544                             180
# 1075112                             180
# 1089560                               4
# 1094050                               4
# 1135405                               4
# 1155647                               4
# 1188654                               4
# 1198968                            2003
# 1199694                            2010
# 1199983                               4
# 1200618                            2010
# 1230395                            2010
# 1231682                               4
# 1238041                               4
# 1257303                            2010
# 1261244                               4
# 1276715                               4
# 1280105                               4
# 1280857                               4
# 1281597                               4
# 1282324                               4
# 1283024                               4
# 1342472                               4
# 1346058                               4
# 1349194                            2014
# 1387687                            2004
# 1412406                          537397
# 1412476                          537397
#
#                                ultimaAcao_tramitacao_orgao  \
# 11463    MESA       - Mesa Diretora da Câmara dos Deput...
# 14254    CCJC       - Comissão de Constituição e Justiç...
# 14318    CCJC       - Comissão de Constituição e Justiç...
# 17265                                PLEN       - PLENÁRIO
# 19590    CCJC       - Comissão de Constituição e Justiç...
# 19649    CCJC       - Comissão de Constituição e Justiç...
# 182934   CCP        - COORDENAÇÃO DE COMISSÕES PERMANENTES
# 187855   MESA       - Mesa Diretora da Câmara dos Deput...
# 187912   MESA       - Mesa Diretora da Câmara dos Deput...
# 187944   MESA       - Mesa Diretora da Câmara dos Deput...
# 234555   MESA       - Mesa Diretora da Câmara dos Deput...
# 235927   MESA       - Mesa Diretora da Câmara dos Deput...
# 261011   MESA       - Mesa Diretora da Câmara dos Deput...
# 269825   MESA       - Mesa Diretora da Câmara dos Deput...
# 296123   MESA       - Mesa Diretora da Câmara dos Deput...
# 308076       CDC        - Comissão de Defesa do Consumidor
# 318298       CDC        - Comissão de Defesa do Consumidor
# 321082   MESA       - Mesa Diretora da Câmara dos Deput...
# 328798                               PLEN       - PLENÁRIO
# 328831                               PLEN       - PLENÁRIO
# 328879                               PLEN       - PLENÁRIO
# 328920                               PLEN       - PLENÁRIO
# 328961                               PLEN       - PLENÁRIO
# 329215                             NaN                        NaN
# 329257                             NaN                        NaN
# ...                                ...                        ...
# 1073488                            NaN                        NaN
# 1073562                            NaN                        NaN
# 1074544                            NaN                        NaN
# 1075112                            NaN                        NaN
# 1089560                            4.0                       MESA
# 1094050                            4.0                       MESA
# 1135405                          180.0                       PLEN
# 1155647                            4.0                       MESA
# 1188654                         2003.0                       CCJC
# 1198968                          180.0                       PLEN
# 1199694                          186.0                        CCP
# 1199983                          186.0                        CCP
# 1200618                          180.0                       PLEN
# 1230395                          180.0                       PLEN
# 1231682                            NaN                        NaN
# 1238041                          186.0                        CCP
# 1257303                          180.0                       PLEN
# 1261244                            4.0                       MESA
# 1276715                            NaN                        NaN
# 1280105                         2003.0                       CCJC
# 1280857                         2003.0                       CCJC
# 1281597                         2003.0                       CCJC
# 1282324                         2003.0                       CCJC
# 1283024                         2003.0                       CCJC
# 1342472                            4.0                       MESA
# 1346058                            4.0                       MESA
# 1349194                          180.0                       PLEN
# 1387687                            4.0                       MESA
# 1412406                          186.0                        CCP
# 1412476                          186.0                        CCP
#
#         andamento_tramitacao_descricao  \
# 11463                              NaN
# 14254                              NaN
# 14318                              NaN
# 17265                              NaN
# 19590                              NaN
# 19649                              NaN
# 182934                             NaN
# 187855                             NaN
# 187912                             NaN
# 187944                             NaN
# 234555                             NaN
# 235927                             NaN
# 261011                             NaN
# 269825                             NaN
# 296123                             NaN
# 308076                             NaN
# 318298                             NaN
# 321082                             NaN
# 328798                             NaN
# 328831                             NaN
# 328879                             NaN
# 328920                             NaN
# 328961                             NaN
# 329001                             NaN
# 329043                             NaN
# 329085                             NaN
# 329132                             NaN
# 329175                             NaN
# 329215                             NaN
# 329257                             NaN
# ...                                ...
# 1073488                            NaN
# 1073562                            NaN
# 1074544                            NaN
# 1075112                            NaN
# 1089560                            NaN
# 1094050                            NaN
# 1135405                            NaN
# 1155647                            NaN
# 1188654                            NaN
# 1198968                            NaN
# 1199694                            NaN
# 1199983                            NaN
# 1200618                            NaN
# 1230395                            NaN
# 1231682                            NaN
# 1238041                            NaN
# 1257303                            NaN
# 1261244                            NaN
# 1276715                            NaN
# 1280105                            NaN
# 1280857                            NaN
# 1281597                            NaN
# 1282324                            NaN
# 1283024                            NaN
# 1342472                            NaN
# 1346058                            NaN
# 1349194                            NaN
# 1387687                            NaN
# 1412406                            NaN
# 1412476                            NaN
#
#                           andamento_tramitacao_inteiroTeor  \
# 11463                                                  NaN
# 14254                                                  NaN
# 14318                                                  NaN
# 17265                                                  NaN
# 19590                                                  NaN
# 19649                                                  NaN
# 182934                                                 NaN
# 187855                                                 NaN
# 187912                                                 NaN
# 187944                                                 NaN
# 234555                                                 NaN
# 235927                                                 NaN
# 261011                                                 NaN
# 269825                                                 NaN
# 296123                                                 NaN
# 308076                                                 NaN
# 318298                                                 NaN
# 321082                                                 NaN
# 328798                                                 NaN
# 328831                                                 NaN
# 328879                                                 NaN
# 328920                                                 NaN
# 328961                                                 NaN
# 329001                                                 NaN
# 329043                                                 NaN
# 329085                                                 NaN
# 329132                                                 NaN
# 329175                                                 NaN
# 329215                                                 NaN
# 329257                                                 NaN
# ...                                                    ...
# 1073488                                                NaN
# 1073562                                                NaN
# 1074544                                                NaN
# 1075112                                                NaN
# 1089560                                                NaN
# 1094050                                                NaN
# 1135405                                                NaN
# 1155647                                                NaN
# 1188654                                                NaN
# 1198968                                                NaN
# 1199694                                                NaN
# 1199983  http://www.camara.gov.br/proposicoesWeb/prop_m...
# 1200618                                                NaN
# 1230395                                                NaN
# 1231682                                                NaN
# 1238041  http://www.camara.gov.br/proposicoesWeb/prop_m...
# 1257303                                                NaN
# 1261244                                                NaN
# 1276715                                                NaN
# 1280105                                                NaN
# 1280857                                                NaN
# 1281597                                                NaN
# 1282324                                                NaN
# 1283024                                                NaN
# 1342472  http://www.camara.gov.br/proposicoesWeb/prop_m...
# 1346058                                                NaN
# 1349194                                                NaN
# 1387687                                                NaN
# 1412406                                                NaN
# 1412476                                                NaN
#
#          andamento_tramitacao_codReuniao andamento_tramitacao_data  \
# 11463                                NaN       2006-01-31 00:00:00
# 14254                                NaN       2016-08-12 00:00:00
# 14318                                NaN       2016-08-12 00:00:00
# 17265                                NaN       2014-11-25 00:00:00
# 19590                                NaN       2016-08-12 00:00:00
# 19649                                NaN       2016-08-12 00:00:00
# 182934                               NaN       2011-03-07 00:00:00
# 187855                               NaN       2012-01-09 00:00:00
# 187912                               NaN       2012-01-09 00:00:00
# 187944                               NaN       2017-12-13 00:00:00
# 234555                               NaN       2017-12-13 00:00:00
# 235927                               NaN       2015-02-13 00:00:00
# 261011                               NaN       2006-04-12 00:00:00
# 269825                               NaN       2011-03-07 00:00:00
# 296123                               NaN       2011-03-07 00:00:00
# 308076                               NaN       2015-11-05 00:00:00
# 318298                               NaN       2015-11-05 00:00:00
# 321082                               NaN       2011-03-07 00:00:00
# 328798                               NaN                       NaN
# 328831                               NaN                       NaN
# 328879                               NaN                       NaN
# 328920                               NaN                       NaN
# 328961                               NaN                       NaN
# 329001                               NaN                       NaN
# 329043                               NaN                       NaN
# 329085                               NaN                       NaN
# 329132                               NaN                       NaN
# 329175                               NaN                       NaN
# 329215                               NaN                       NaN
# 329257                               NaN                       NaN
# ...                                  ...                       ...
# 1073488                              NaN                       NaN
# 1073562                              NaN                       NaN
# 1074544                              NaN                       NaN
# 1075112                              NaN                       NaN
# 1089560                              NaN       2014-04-08 00:00:00
# 1094050                              NaN       2011-03-29 00:00:00
# 1135405                              NaN       2011-03-07 00:00:00
# 1155647                              NaN       2017-12-13 00:00:00
# 1188654                              NaN       2006-01-31 00:00:00
# 1198968                              NaN       2011-03-07 00:00:00
# 1199694                              NaN       2011-07-12 00:00:00
# 1199983                              NaN       2011-09-09 00:00:00
# 1200618                              NaN       2011-03-07 00:00:00
# 1230395                              NaN       2011-03-07 00:00:00
# 1231682                              NaN                       NaN
# 1238041                              NaN       2011-09-09 00:00:00
# 1257303                              NaN       2011-03-07 00:00:00
# 1261244                              NaN       2014-04-08 00:00:00
# 1276715                              NaN                       NaN
# 1280105                              NaN       2006-01-31 00:00:00
# 1280857                              NaN       2006-01-31 00:00:00
# 1281597                              NaN       2006-01-31 00:00:00
# 1346058                                    32.0  2018-03-23 03:10:00
# 1349194                                    46.0  2018-03-22 23:19:46
# 1387687                                    55.0  2018-03-23 00:13:13
# 1412406                                    13.0  2018-03-22 18:17:45
# 1412476                                    14.0  2018-03-22 18:17:45
#
# [335 rows x 21 columns]

# %%
trams_pls_full = trams_pls[~trams_pls.andamento_tramitacao_descricao.isnull()][['andamento_tramitacao_descricao']]

# %%
trams_pls_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1428572 entries, 0 to 1428906
# Data columns (total 1 columns):
# andamento_tramitacao_descricao    1428572 non-null object
# dtypes: object(1)
# memory usage: 21.8+ MB

# %%
trams_pls_full.head()
# Out:
#                       andamento_tramitacao_descricao
# 0  Apresentação do Parecer do Relator, PRL 3 CIND...
# 1             Apense-se a este(a) o(a) PL-1915/2015.
# 2  Sujeito a arquivamento, nos termos do § 4º do ...
# 3  Apense-se à(ao) PL-5089/2013.Proposição Sujeit...
# 4                            Recebimento pela CDEIC.

# %% [markdown]
# <a id = 'amostra'></a>
# ### Amostragem

# %% [markdown]
# Selecionamos então uma amostra aleatória correspondente a 10% do total das tramitações para analisar os dados, cerca de 140 mil tramitações.

# %%
#trams_sample = trams_pls_full.sample(round(len(trams_pls_full)*0.1))

trams_sample = pd.read_csv('trams_sample.csv')

trams_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142857 entries, 238409 to 25999
# Data columns (total 1 columns):
# andamento_tramitacao_descricao    142857 non-null object
# dtypes: object(1)
# memory usage: 2.2+ MB

# %%
#trams_sample.to_csv(DATASET+'trams_sample.csv')

# %% [markdown]
# Dessa amostra, 60% será destinada para treino e 40% para teste.

# %%
#trams_train = trams_sample.sample(round(len(trams_sample)*0.6))
#trams_test = trams_sample.loc[trams_sample.index.difference(trams_train.index)]

trams_train = pd.read_csv(DATASET+'trams_train.csv')

trams_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85714 entries, 466267 to 728079
# Data columns (total 1 columns):
# andamento_tramitacao_descricao    85714 non-null object
# dtypes: object(1)
# memory usage: 1.3+ MB

# %%
trams_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57143 entries, 16 to 1428905
# Data columns (total 1 columns):
# andamento_tramitacao_descricao    57143 non-null object
# dtypes: object(1)
# memory usage: 892.9+ KB

# %%
#trams_train.to_csv(DATASET+'trams_train.csv')
#trams_test.to_csv(DATASET+'trams_test.csv')

# %% [markdown]
# ### Limpeza e análise textual

# %%
list(trams_train.andamento_tramitacao_descricao)[:10]
# Out:
# ['Recebido o Ofício n. 976/15, da CAPADR, comunicando que o PL n. 6.837/2013 recebeu pareceres divergentes nas comissões que lhe apreciaram o mérito.',
#  'Recebimento pela CFT, com as proposições PL-8225/2014, PL-209/2015 apensadas.',
#  'Arquivado nos termos do Artigo 105 do Regimento Interno. DCD 01 02 07 PAG 143 COL 01 SUPLEMENTO 01 AO Nº  21.',
#  'Publicação inicial no DCD de 11/02/11 PÁG 5818 COL 02.',
#  'Designado Relator, Dep. Mendes Ribeiro Filho (PMDB-RS)',
#  'Abertura de Prazo para Emendas ao Projeto a partir de 14/05/2003',
#  'Apresentação do Requerimento de Desapensação n. 4893/2016, pelo Deputado Rômulo Gouveia (PSD-PB), que: "Requer, nos termos regimentais, a desapensação do Projeto de Lei nº 4827/2016, apensado ao Projeto de Lei nº 7231/2014, com a finalidade de tramitarem em separados".',
#  'Recebimento pela CSSF.',
#  'Matéria não apreciada em face da não conclusão da apreciação da MPV 279/06, item 02 da pauta, com prazo encerrado.',
#  'Retirado o destaque da Bancada do PT, para votação em separado de expressão constante da Subemenda Substitutiva Global.']

# %% [markdown]
# Agrupamos os textos para verificarmos detalhes sobre as palavras, como sua frequẽncia, "sinônimos", similaridade, etc.

# %%
trams_train['text'] = trams_train['andamento_tramitacao_descricao'] + ' '
texts = trams_train['text'].sum()

# %%
texts[0:1200]
# Out:
# 'Recebido o Ofício n. 976/15, da CAPADR, comunicando que o PL n. 6.837/2013 recebeu pareceres divergentes nas comissões que lhe apreciaram o mérito. Recebimento pela CFT, com as proposições PL-8225/2014, PL-209/2015 apensadas. Arquivado nos termos do Artigo 105 do Regimento Interno. DCD 01 02 07 PAG 143 COL 01 SUPLEMENTO 01 AO Nº  21. Publicação inicial no DCD de 11/02/11 PÁG 5818 COL 02. Designado Relator, Dep. Mendes Ribeiro Filho (PMDB-RS) Abertura de Prazo para Emendas ao Projeto a partir de 14/05/2003 Apresentação do Requerimento de Desapensação n. 4893/2016, pelo Deputado Rômulo Gouveia (PSD-PB), que: "Requer, nos termos regimentais, a desapensação do Projeto de Lei nº 4827/2016, apensado ao Projeto de Lei nº 7231/2014, com a finalidade de tramitarem em separados". Recebimento pela CSSF. Matéria não apreciada em face da não conclusão da apreciação da MPV 279/06, item 02 da pauta, com prazo encerrado. Retirado o destaque da Bancada do PT, para votação em separado de expressão constante da Subemenda Substitutiva Global. Prejudicado o Requerimento de Retirada de Pauta em virtude da ausência de seu autor no plenário no momento do anúncio do Requerimento. Aprovada a Redação Final p'

# %% [markdown]
# Para analisarmos os dados textuais, primeiramente devemos limpar esses dados:
#
# 1. **Removendo pontuações e *stop words***, palavras consideradas irrelevantes para a classificação do texto, como conjunções, artigos. Essas palavras comumente tem alta frequência, pois aparecem em muitos textos, mas não agregam significado.

# %%
stop_pt = nltk.corpus.stopwords.words('portuguese')

list_words = texts.split()
list_words = [l.strip().lower() for l in list_words]
list_words = [l.strip(string.punctuation) for l in list_words] 
list_words = [l for l in list_words if l not in stop_pt]

freqdist = Counter(list_words)
freqdist.most_common(50)
# Out:
# [('dep', 20242),
#  ('relator', 17557),
#  ('parecer', 16794),
#  ('projeto', 15921),
#  ('apresentação', 15608),
#  ('publicação', 14479),
#  ('emendas', 14032),
#  ('col', 13582),
#  ('art', 12861),
#  ('n', 11958),
#  ('prazo', 11387),
#  ('lei', 11173),
#  ('dcd', 10747),
#  ('01', 10450),
#  ('pl', 9705),
#  ('deputado', 9356),
#  ('', 8612),
#  ('ricd', 7873),
#  ('termos', 7593),
#  ('artigo', 7549),
#  ('nº', 7184),
#  ('pag', 7104),
#  ('requerimento', 7103),
#  ('pág', 6526),
#  ('recebimento', 6178),
#  ('proposição', 6123),
#  ('despacho', 5732),
#  ('02', 5636),
#  ('encaminhada', 5587),
#  ('inicial', 5425),
#  ('24', 5278),
#  ('comissão', 5210),
#  ('comissões', 5122),
#  ('sessões', 4913),
#  ('designado', 4885),
#  ('aprovação', 4675),
#  ('apreciação', 4674),
#  ('tramitação', 4622),
#  ('apresentadas', 4545),
#  ('encerrado', 4386),
#  ('partir', 4358),
#  ('54', 4336),
#  ('ii', 4209),
#  ('sujeita', 4093),
#  ('apense-se', 4077),
#  ('105', 3987),
#  ('5', 3928),
#  ('desarquivamento', 3898),
#  ('substitutivo', 3891),
#  ('regime', 3698)]

# %% [markdown]
# Dentre as 50 palavras mais frequentes, podemos ver que temos repetições por abreviações, como "deputado" e "dep", "artigo" e "art".
#
# **Também observamos alta ocorrência de valores numéricos, que vamos descartar.** Esses números são possivelmente proveninetes de datas, paginações, etc, que não nos interessam para a categorização dos textos.

# %%
list_words = [l for l in list_words if not any([c.isdigit() for c in l])]

freqdist = Counter(list_words)
freqdist.most_common(50)
# Out:
# [('dep', 20242),
#  ('relator', 17557),
#  ('parecer', 16794),
#  ('projeto', 15921),
#  ('apresentação', 15608),
#  ('publicação', 14479),
#  ('emendas', 14032),
#  ('col', 13582),
#  ('art', 12861),
#  ('n', 11958),
#  ('prazo', 11387),
#  ('lei', 11173),
#  ('dcd', 10747),
#  ('pl', 9705),
#  ('deputado', 9356),
#  ('', 8612),
#  ('ricd', 7873),
#  ('termos', 7593),
#  ('artigo', 7549),
#  ('nº', 7184),
#  ('pag', 7104),
#  ('requerimento', 7103),
#  ('pág', 6526),
#  ('recebimento', 6178),
#  ('proposição', 6123),
#  ('despacho', 5732),
#  ('encaminhada', 5587),
#  ('inicial', 5425),
#  ('comissão', 5210),
#  ('comissões', 5122),
#  ('sessões', 4913),
#  ('designado', 4885),
#  ('aprovação', 4675),
#  ('apreciação', 4674),
#  ('tramitação', 4622),
#  ('apresentadas', 4545),
#  ('encerrado', 4386),
#  ('partir', 4358),
#  ('ii', 4209),
#  ('sujeita', 4093),
#  ('apense-se', 4077),
#  ('desarquivamento', 3898),
#  ('substitutivo', 3891),
#  ('regime', 3698),
#  ('avulso', 3459),
#  ('regimento', 3361),
#  ('constituição', 3311),
#  ('interno', 3310),
#  ('deputados', 3053),
#  ('justiça', 3050)]

# %% [markdown]
# Devemos remover também acentuações para não repetimos palavras, como `pág` e `pag`.

# %%
import unidecode

list_words = [unidecode.unidecode(l) for l in list_words]
freqdist = Counter(list_words)
freqdist.most_common(50)
# Out:
# [('dep', 20242),
#  ('relator', 17557),
#  ('parecer', 16794),
#  ('projeto', 15921),
#  ('apresentacao', 15610),
#  ('publicacao', 14481),
#  ('emendas', 14032),
#  ('pag', 13630),
#  ('col', 13582),
#  ('art', 12861),
#  ('n', 11958),
#  ('prazo', 11387),
#  ('lei', 11173),
#  ('dcd', 10747),
#  ('pl', 9705),
#  ('deputado', 9356),
#  ('', 8612),
#  ('ricd', 7873),
#  ('termos', 7593),
#  ('artigo', 7549),
#  ('no', 7184),
#  ('requerimento', 7103),
#  ('recebimento', 6178),
#  ('proposicao', 6124),
#  ('despacho', 5732),
#  ('encaminhada', 5587),
#  ('inicial', 5425),
#  ('comissao', 5210),
#  ('comissoes', 5122),
#  ('sessoes', 4914),
#  ('designado', 4885),
#  ('aprovacao', 4676),
#  ('apreciacao', 4674),
#  ('tramitacao', 4622),
#  ('apresentadas', 4545),
#  ('encerrado', 4386),
#  ('partir', 4358),
#  ('ii', 4209),
#  ('sujeita', 4093),
#  ('apense-se', 4077),
#  ('desarquivamento', 3898),
#  ('substitutivo', 3891),
#  ('regime', 3698),
#  ('avulso', 3459),
#  ('regimento', 3361),
#  ('constituicao', 3312),
#  ('interno', 3310),
#  ('deputados', 3053),
#  ('justica', 3050),
#  ('ccjc', 3031)]

# %%
labels, values = zip(*freqdist.most_common(50))

trace = go.Bar(x=labels, y=values)
layout = go.Layout(title='Frequência de palavras nos textos de tramitação', 
                  yaxis=dict(title='Número de ocorrências'), xaxis=dict(tickangle=55))

fig = go.Figure(data=[trace], layout=layout)
offline.iplot(fig)
# Out:
# <div id="50fe86af-cfcf-4ace-8cb0-93718fda8c11" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("50fe86af-cfcf-4ace-8cb0-93718fda8c11", [{"y": [20242, 17557, 16794, 15921, 15610, 14481, 14032, 13630, 13582, 12861, 11958, 11387, 11173, 10747, 9705, 9356, 8612, 7873, 7593, 7549, 7184, 7103, 6178, 6124, 5732, 5587, 5425, 5210, 5122, 4914, 4885, 4676, 4674, 4622, 4545, 4386, 4358, 4209, 4093, 4077, 3898, 3891, 3698, 3459, 3361, 3312, 3310, 3053, 3050, 3031], "type": "bar", "x": ["dep", "relator", "parecer", "projeto", "apresentacao", "publicacao", "emendas", "pag", "col", "art", "n", "prazo", "lei", "dcd", "pl", "deputado", "", "ricd", "termos", "artigo", "no", "requerimento", "recebimento", "proposicao", "despacho", "encaminhada", "inicial", "comissao", "comissoes", "sessoes", "designado", "aprovacao", "apreciacao", "tramitacao", "apresentadas", "encerrado", "partir", "ii", "sujeita", "apense-se", "desarquivamento", "substitutivo", "regime", "avulso", "regimento", "constituicao", "interno", "deputados", "justica", "ccjc"]}], {"yaxis": {"title": "N\u00famero de ocorr\u00eancias"}, "title": "Frequ\u00eancia de palavras nos textos de tramita\u00e7\u00e3o", "xaxis": {"tickangle": 55}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# Outros detalhe é que temos repetições de palavras através de flexões nominais e verbais, que carregam o mesmo significado. Temos um exemplo abaixo:

# %%
print(freqdist['encaminhada'])
print(freqdist['encaminhado'])
print(freqdist['encaminhamento'])
# Out:
# 5587
# 1246
# 800

# %% [markdown]
# Logo, para evitar esse tipo de repetição, vamos reduzir as palavras aos seu radicais!

# %%
list_words = list(filter(lambda x: x != '', list_words)) # removing empty str

# %%
stemmer = nltk.stem.RSLPStemmer()

list_words2 = [stemmer.stem(l) for l in list_words]

freqdist2 = Counter(list_words2)
freqdist2.most_common(50)
# Out:
# [('dep', 20251),
#  ('rela', 19205),
#  ('parec', 17114),
#  ('projet', 16732),
#  ('emend', 16167),
#  ('apresentaca', 15610),
#  ('publicaca', 14481),
#  ('pag', 13744),
#  ('col', 13602),
#  ('deput', 13524),
#  ('art', 13008),
#  ('n', 11958),
#  ('lei', 11482),
#  ('praz', 11421),
#  ('dcd', 10898),
#  ('pl', 9865),
#  ('receb', 8740),
#  ('encaminh', 8168),
#  ('ricd', 7873),
#  ('no', 7661),
#  ('artig', 7650),
#  ('term', 7605),
#  ('requer', 7225),
#  ('proposica', 6124),
#  ('apresent', 5816),
#  ('despach', 5755),
#  ('encerr', 5650),
#  ('design', 5555),
#  ('inic', 5442),
#  ('desarquiv', 5422),
#  ('ordin', 5388),
#  ('comissa', 5210),
#  ('comisso', 5122),
#  ('sesso', 4914),
#  ('sujeit', 4815),
#  ('aprovaca', 4676),
#  ('apreciaca', 4674),
#  ('tramitaca', 4622),
#  ('part', 4478),
#  ('ii', 4211),
#  ('apense-s', 4077),
#  ('substitu', 4050),
#  ('regim', 3702),
#  ('dest', 3684),
#  ('avuls', 3463),
#  ('reg', 3454),
#  ('arquiv', 3437),
#  ('intern', 3315),
#  ('constituica', 3312),
#  ('apens', 3286)]

# %% [markdown]
# **O problema dessa redução ao radical é que perdemos o significado de muitas palavras!**
#
# Por exemplo, olhando para o 2º termo mais frequente, "rela", não sabemos exatamente quais palavras podem ter esse radical, pois é algo muito genérico. Por exemĺo, "relação", "relatoria", e outras palavras que têm diferentes significados podem ter sido reduzidas a esse radical.

# %%
labels, values = zip(*freqdist2.most_common(50))

trace = go.Bar(x=labels, y=values)
layout = go.Layout(title='Frequência dos radicais nos textos de tramitação', 
                  yaxis=dict(title='Número de ocorrências'), xaxis=dict(tickangle=55))

fig = go.Figure(data=[trace], layout=layout)
offline.iplot(fig)
# Out:
# <div id="cded8fe5-d3ea-45ba-a382-e5c1f1209356" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cded8fe5-d3ea-45ba-a382-e5c1f1209356", [{"y": [20251, 19205, 17114, 16732, 16167, 15610, 14481, 13744, 13602, 13524, 13008, 11958, 11482, 11421, 10898, 9865, 8740, 8168, 7873, 7661, 7650, 7605, 7225, 6124, 5816, 5755, 5650, 5555, 5442, 5422, 5388, 5210, 5122, 4914, 4815, 4676, 4674, 4622, 4478, 4211, 4077, 4050, 3702, 3684, 3463, 3454, 3437, 3315, 3312, 3286], "type": "bar", "x": ["dep", "rela", "parec", "projet", "emend", "apresentaca", "publicaca", "pag", "col", "deput", "art", "n", "lei", "praz", "dcd", "pl", "receb", "encaminh", "ricd", "no", "artig", "term", "requer", "proposica", "apresent", "despach", "encerr", "design", "inic", "desarquiv", "ordin", "comissa", "comisso", "sesso", "sujeit", "aprovaca", "apreciaca", "tramitaca", "part", "ii", "apense-s", "substitu", "regim", "dest", "avuls", "reg", "arquiv", "intern", "constituica", "apens"]}], {"yaxis": {"title": "N\u00famero de ocorr\u00eancias"}, "title": "Frequ\u00eancia dos radicais nos textos de tramita\u00e7\u00e3o", "xaxis": {"tickangle": 55}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# Uma saída é fazermos a lematização das palavras utilizando o pacote `textblob`

# %%
from textblob import Word

list_words3 = [Word(l).lemmatize() for l in list_words]

freqdist3 = Counter(list_words3)
freqdist3.most_common(50)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-229-abc965b8dc1c> in <module>()
# ----> 1 from textblob import TextBlob
#       2 from textblob import Word
#
# ImportError: No module named 'textblob'

# %%
labels, values = zip(*freqdist3.most_common(50))

trace = go.Bar(x=labels, y=values)
layout = go.Layout(title='Frequência dos lemas nos textos de tramitação', 
                  yaxis=dict(title='Número de ocorrências'), xaxis=dict(tickangle=55))

fig = go.Figure(data=[trace], layout=layout)
offline.iplot(fig)
